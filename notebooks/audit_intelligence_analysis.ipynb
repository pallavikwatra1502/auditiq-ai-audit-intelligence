# %% [markdown]
# # AuditIQ — Audit Intelligence Analysis
#
# This notebook explains the data analysis, risk scoring and reporting logic used by the Streamlit app.

# %%
import pandas as pd
df = pd.read_csv("../data/sample_audit_findings.csv")
df.head()

# %% [markdown]
# ## Analysis Areas
# - Severity distribution
# - Evidence completeness
# - Overdue remediation
# - Regulatory impact
# - Risk scoring logic
# - Management summary generation

# %%
df.groupby(["severity", "status"]).size().unstack(fill_value=0)

# %%
df["evidence_status"].value_counts()
